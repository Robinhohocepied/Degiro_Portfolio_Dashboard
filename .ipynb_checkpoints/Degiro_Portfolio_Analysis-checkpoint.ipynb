# %%
import sys
import degiroapi
from degiroapi.product import Product
from degiroapi.order import Order
from degiroapi.utils import pretty_json
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import getpass
import json

#!{sys.executable} -m pip install urllib2
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib2 (from versions: none)
# ERROR: No matching distribution found for urllib2

# %% [markdown]
# ### API Connection

# %%
#Create safe method for password
password = getpass.getpass('YourPassword')
print('Your password is: ' + password)

# %%
# login to Degiro
degiro = degiroapi.DeGiro()
degiro.login("RobinHocepied", password)
# Out:
# {'data': {'id': 501261,
#   'intAccount': 11025519,
#   'loggedInPersonId': 503705,
#   'clientRole': 'active',
#   'effectiveClientRole': 'active',
#   'contractType': 'PRIVATE',
#   'username': 'RobinHocepied',
#   'displayName': 'ROBIN JEAN C HOCEPIED',
#   'email': 'robinhocepied@gmail.com',
#   'firstContact': {'firstName': 'ROBIN JEAN C',
#    'lastName': 'HOCEPIED',
#    'displayName': 'ROBIN JEAN C HOCEPIED',
#    'nationality': 'BE',
#    'gender': 'MALE',
#    'dateOfBirth': '1993-05-24',
#    'placeOfBirth': 'Verviers',
#    'countryOfBirth': 'BE'},
#   'address': {'streetAddress': 'Rue Gérard',
#    'streetAddressNumber': '64',
#    'streetAddressExt': 'Etterbeek',
#    'zip': '1040',
#    'city': 'Bruxelles',
#    'country': 'BE'},
#   'cellphoneNumber': '+32471991561',
#   'locale': 'fr_BE',
#   'language': 'fr',
#   'culture': 'BE',
#   'displayLanguage': 'fr',
#   'bankAccount': {'bankAccountId': 508936,
#    'bic': 'CREGBEBBXXX',
#    'iban': 'BE58732028811879',
#    'status': 'VERIFIED'},
#   'flatexBankAccount': {'bic': 'BIWBDE33XXX',
#    'iban': 'DE73101308001017447600'},
#   'memberCode': 'EA0EF874',
#   'isWithdrawalAvailable': True,
#   'isAllocationAvailable': True,
#   'isIskClient': False,
#   'isCollectivePortfolio': False,
#   'isAmClientActive': False,
#   'canUpgrade': True}}

# %% [markdown]
# ### Get Portfolio positions

# %%
portfolio = degiro.getdata(degiroapi.Data.Type.PORTFOLIO, True)
df = pd.DataFrame(portfolio)
df.head(5)
# Out:
#          id positionType   size  price        value  breakEvenPrice
# 0  18343191      PRODUCT    1.0  39.99    35.447136       36.710000
# 1  19790636      PRODUCT   20.0   4.40    78.003200        5.210000
# 2  18333971      PRODUCT    1.0  21.41    18.977824       28.311741
# 3  19433248      PRODUCT   10.0   2.17    19.234880        3.892857
# 4  16204538      PRODUCT  401.0   3.08  1094.774912        5.211147

# %%
#Delete CASH in positionType
i = df[(df.positionType == "CASH")].index
df.drop(i, inplace=True)

# %%
df['pct_of_total'] = ((df['value']/df['value'].sum())*100).round(2)
df.head()
# Out:
#          id positionType   size  price        value  breakEvenPrice  \
# 0  18343191      PRODUCT    1.0  39.99    35.447136       36.710000
# 1  19790636      PRODUCT   20.0   4.40    78.003200        5.210000
# 2  18333971      PRODUCT    1.0  21.41    18.977824       28.311741
# 3  19433248      PRODUCT   10.0   2.17    19.234880        3.892857
# 4  16204538      PRODUCT  401.0   3.08  1094.774912        5.211147
#
#    pct_of_total
# 0          0.27
# 1          0.59
# 2          0.14
# 3          0.15
# 4          8.34

# %%
df.describe()
# Out:
#              size       price        value  breakEvenPrice  pct_of_total
# count   57.000000   57.000000    57.000000       57.000000     57.000000
# mean    17.175439   92.554561   230.330744       95.419775      1.754561
# std     60.587046   96.053969   592.012459       94.631415      4.509487
# min      1.000000    1.630000     5.832512        1.380000      0.040000
# 25%      1.000000   20.540000    49.450000       24.810634      0.380000
# 50%      1.000000   49.450000   124.397376       72.000000      0.950000
# 75%      4.000000  140.950000   199.564096      126.233204      1.520000
# max    401.000000  368.780000  4438.736640      405.045937     33.810000

# %% [markdown]
# ### Get Stock Names

# %%
responses = [degiro.product_info(x) for x in df['id'].values]
df_responses = pd.DataFrame(responses)

# %%
df_responses.head()
# Out:
#          id                                    name          isin symbol  \
# 0  18343191                     Goodrx Holdings Inc  US38246G1085   GDRX
# 1  19790636  FIELD TRIP HEALTH LTD. - COMMON SHARES  CA31656R1029   FTRP
# 2  18333971               Palantir Technologies Inc  US69608A1088   PLTR
# 3  19433248       FLORA GROWTH CORP. - COMMON STOCK  CA3397641026   FLGC
# 4  16204538        Douyu International Holdings Ltd  US25985W1053   DOYU
#
#    contractSize productType  productTypeId  tradable category currency  ...  \
# 0           1.0       STOCK              1      True        C      USD  ...
# 1           1.0       STOCK              1      True        D      USD  ...
# 2           1.0       STOCK              1      True        D      USD  ...
# 3           1.0       STOCK              1      True        D      USD  ...
# 4           1.0       STOCK              1      True        C      USD  ...
#
#   qualitySwitchable qualitySwitchFree vwdModuleId feedQualitySecondary  \
# 0             False             False        31.0                  D15
# 1              True             False        21.0                  NaN
# 2             False             False        31.0                  D15
# 3              True             False        21.0                  NaN
# 4             False             False        31.0                  D15
#
#   orderBookDepthSecondary vwdIdentifierTypeSecondary vwdIdSecondary  \
# 0                     0.0                    issueid      600122373
# 1                     NaN                        NaN            NaN
# 2                     0.0                    issueid      600121287
# 3                     NaN                        NaN            NaN
# 4                     0.0                    issueid      600098927
#
#    qualitySwitchableSecondary qualitySwitchFreeSecondary vwdModuleIdSecondary
# 0                        True                      False                 21.0
# 1                         NaN                        NaN                  NaN
# 2                       False                      False                 10.0
# 3                         NaN                        NaN                  NaN
# 4                        True                      False                 21.0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Merge Portfolio and Stock Names

# %%
from datetime import datetime, timedelta

transactions = degiro.transactions(datetime(2018, 1, 1), datetime.now())

# %%
df_transactions = pd.DataFrame(transactions)

# %%
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 869 entries, 0 to 868
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          869 non-null    int64
#  1   productId                   869 non-null    int64
#  2   date                        869 non-null    object
#  3   buysell                     869 non-null    object
#  4   price                       869 non-null    float64
#  5   quantity                    869 non-null    int64
#  6   total                       869 non-null    float64
#  7   orderTypeId                 863 non-null    float64
#  8   counterParty                863 non-null    object
#  9   transfered                  869 non-null    bool
#  10  fxRate                      869 non-null    float64
#  11  totalInBaseCurrency         869 non-null    float64
#  12  feeInBaseCurrency           852 non-null    float64
#  13  totalPlusFeeInBaseCurrency  869 non-null    float64
#  14  transactionTypeId           869 non-null    int64
#  15  tradingVenue                789 non-null    object
# dtypes: bool(1), float64(7), int64(4), object(4)
# memory usage: 102.8+ KB

# %%
import degiroapi
from degiroapi.product import Product
from degiroapi.order import Order
from degiroapi.utils import pretty_json

import pandas as pd
import numpy as np

from datetime import datetime, timedelta

# login
degiro = degiroapi.DeGiro()
degiro.login("RobinHocepied", "Jeancharles146124%")

  
# getting realtime and historical data from a stock
products = degiro.search_products('PINS')
high=[]
nb = []


for x in range(2):
        realprice = degiro.real_time_price(Product(products[0]).id, degiroapi.Interval.Type.Max)  
        rp = realprice[0]['data']['lastPrice']
        print(high)
    
        #time.sleep(60)
        realprice1 = degiro.real_time_price(Product(products[0]).id, degiroapi.Interval.Type.Max)  
        rp1 = realprice1[0]['data']['lastPrice']
        if rp1 > rp:
            rp3 = 0.97*rp1
            high.append(rp1*0.97)
            nb.append(1)
            degiro.buyorder(Order.Type.LIMIT, Product(products[0]).id, 3, 1, round(rp3,2))
            if len(nb) == 0: 
                break
            break
        break
            
        print(high)
        print(nb)
# Out:
# []
