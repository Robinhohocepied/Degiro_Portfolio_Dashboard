# %%
import sys
import degiroapi
from degiroapi.product import Product
from degiroapi.order import Order
from degiroapi.utils import pretty_json
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import getpass
import json
import matplotlib.pyplot as plt
import seaborn as sb
from selenium import webdriver
from bs4 import BeautifulSoup
import urllib.request
import csv
from pandas import ExcelWriter
import yfinance as yf
pd.options.display.float_format = '{:.0f}'.format
import requests
import pickle
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2
from time import sleep
from random import randint
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
import folium
from folium.plugins import MarkerCluster
import yahoo_fin.stock_info as si

# %%
#!{sys.executable} -m pip install yahoo_fin

# %% [markdown]
# ### API Connection

# %%
#Create safe method for password
password = getpass.getpass('YourPassword')
print('Your password is: ' + password)

# %%
# login to Degiro
degiro = degiroapi.DeGiro()
degiro.login("RobinHocepied", password)

# %% [markdown]
# ### Get Portfolio positions

# %%
#Get pf positions
portfolio = degiro.getdata(degiroapi.Data.Type.PORTFOLIO, True)
portfolio_df = pd.DataFrame(portfolio)
portfolio_df.head(5)
# Out:
#          id positionType  size  price  value  breakEvenPrice
# 0  18343191      PRODUCT     1     31     27              37
# 1  19790636      PRODUCT    20      2     42               5
# 2  18333971      PRODUCT     1     18     16              28
# 3  19433248      PRODUCT    40      2     77               3
# 4  16204538      PRODUCT   401      2    856               5

# %%
#Delete CASH in positionType
i = portfolio_df[(portfolio_df.positionType == "CASH")].index
portfolio_df.drop(i, inplace=True)

# %%
#Compute position's %
portfolio_df['pct_of_total'] = ((portfolio_df['value']/portfolio_df['value'].sum())*100).round(2)
portfolio_df.head()
# Out:
#          id positionType  size  price  value  breakEvenPrice  pct_of_total
# 0  18343191      PRODUCT     1     33     29              37             0
# 1  19790636      PRODUCT    20      2     43               5             0
# 2  18333971      PRODUCT     1     19     17              28             0
# 3  19433248      PRODUCT    10      2     16               4             0
# 4  16204538      PRODUCT   401      2    864               5             8

# %%
#Get statistics
portfolio_df.describe()
# Out:
#        size  price  value  breakEvenPrice  pct_of_total
# count    54     54     54              54            54
# mean     18     69    191              92             2
# std      61     70    516              96             5
# min       1      1      6               1             0
# 25%       1     17     41              25             0
# 50%       1     43    101              66             1
# 75%       5    110    165             123             2
# max     401    286   3783             405            37

# %%
# Portfolio weights
# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.hist(portfolio_df.pct_of_total,  bins=100)
plt.show()

# %%
#Boxplot
sb.boxplot(x = 'pct_of_total', data = portfolio_df, showfliers = True)
# Out:
# <AxesSubplot:xlabel='pct_of_total'>

# %% [markdown]
# ### Get Stock Names

# %%
#Get Stock Names
stock_names = [degiro.product_info(x) for x in portfolio_df['id'].values]
stock_names_df = pd.DataFrame(stock_names)
stock_names_df.head()
# Out:
#          id                                    name          isin symbol  \
# 0  18343191                     Goodrx Holdings Inc  US38246G1085   GDRX
# 1  19790636  FIELD TRIP HEALTH LTD. - COMMON SHARES  CA31656R1029   FTRP
# 2  18333971               Palantir Technologies Inc  US69608A1088   PLTR
# 3  19433248       FLORA GROWTH CORP. - COMMON STOCK  CA3397641026   FLGC
# 4  16204538        Douyu International Holdings Ltd  US25985W1053   DOYU
#
#    contractSize productType  productTypeId  tradable category currency  ...  \
# 0             1       STOCK              1      True        C      USD  ...
# 1             1       STOCK              1      True        D      USD  ...
# 2             1       STOCK              1      True        D      USD  ...
# 3             1       STOCK              1      True        D      USD  ...
# 4             1       STOCK              1      True        C      USD  ...
#
# ...

# %%
#Only keep Name and Symbol
stock_names_df = stock_names_df[['id','name','symbol']]
stock_names_df.head()
# Out:
#          id                                    name symbol
# 0  18343191                     Goodrx Holdings Inc   GDRX
# 1  19790636  FIELD TRIP HEALTH LTD. - COMMON SHARES   FTRP
# 2  18333971               Palantir Technologies Inc   PLTR
# 3  19433248       FLORA GROWTH CORP. - COMMON STOCK   FLGC
# 4  16204538        Douyu International Holdings Ltd   DOYU

# %% [markdown]
# ### Merge Portfolio and Stock Names

# %%
portfolio_stock_df = portfolio_df.merge(stock_names_df, how='left', on='id')

# %%
portfolio_stock_df.head(5)
# Out:
#          id positionType  size  price  value  breakEvenPrice  pct_of_total  \
# 0  18343191      PRODUCT     1     33     29              37             0
# 1  19790636      PRODUCT    20      2     43               5             0
# 2  18333971      PRODUCT     1     19     17              28             0
# 3  19433248      PRODUCT    10      2     16               4             0
# 4  16204538      PRODUCT   401      2    864               5             8
#
#                                      name symbol  unrealized_gains
# 0                     Goodrx Holdings Inc   GDRX                -3
# 1  FIELD TRIP HEALTH LTD. - COMMON SHARES   FTRP               -55
# 2               Palantir Technologies Inc   PLTR                -9
# 3       FLORA GROWTH CORP. - COMMON STOCK   FLGC               -21
# 4        Douyu International Holdings Ltd   DOYU             -1111

# %% [markdown]
# ### API Yahoo Finance

# %% [markdown]
# https://finance.yahoo.com/quote/GDRX?p=GDRX

# %% [markdown]
# #### Price

# %%
# Initializing the Ticker object and get the history
goldman_sachs = yf.Ticker('GDRX')
goldman_sachs_df = goldman_sachs.history(period='max')

# %%
goldman_sachs_df.head()
# Out:
#             Open  High  Low  Close    Volume  Dividends  Stock Splits
# Date
# 2020-09-23    47    52   46     50  22724400          0             0
# 2020-09-24    49    50   46     47   5098300          0             0
# 2020-09-25    48    53   47     52   4213000          0             0
# 2020-09-28    53    61   52     57   7039600          0             0
# 2020-09-29    59    64   53     56  10504600          0             0

# %% [markdown]
# #### Stats

# %%
quote_table = si.get_quote_table("aapl", dict_result=False)
quote_table
# Out:
#                    attribute                        value
# 0              1y Target Est                          176
# 1              52 Week Range              116.21 - 182.13
# 2                        Ask                178.25 x 1200
# 3                Avg. Volume                     88976285
# 4          Beta (5Y Monthly)                            1
# 5                        Bid                 178.21 x 800
# 6                Day's Range              177.26 - 179.23
# 7                  EPS (TTM)                            6
# 8              Earnings Date  Jan 25, 2022 - Jan 31, 2022
# 9           Ex-Dividend Date                 Nov 05, 2021
# 10  Forward Dividend & Yield                 0.88 (0.50%)
# 11                Market Cap                       2.913T
# 12                      Open                          178
# 13            PE Ratio (TTM)                           32
# 14            Previous Close                          178
# ...

# %%
si.get_stats_valuation("GDRX")
# Out:
#                            0       1
# 0      Market Cap (intraday)  15.93B
# 1           Enterprise Value  15.72B
# 2               Trailing P/E  871.85
# 3                Forward P/E   75.19
# 4  PEG Ratio (5 yr expected)     NaN
# 5          Price/Sales (ttm)   24.08
# 6           Price/Book (mrq)   18.82
# 7   Enterprise Value/Revenue   22.92
# 8    Enterprise Value/EBITDA  -58.33

# %%
dow_stats = {}
for ticker in stock_symbol_list:
    temp = si.get_stats_valuation(ticker)
    temp = temp.iloc[:,:2]
    temp.columns = ["Attribute", "Recent"]
    dow_stats[ticker] = temp
dow_stats
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17516/4291501496.py in <module>
#       1 dow_stats = {}
#       2 for ticker in stock_symbol_list:
# ----> 3     temp = si.get_stats_valuation(ticker)
#       4     temp = temp.iloc[:,:2]
#       5     temp.columns = ["Attribute", "Recent"]
#
# ~\anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_stats_valuation(ticker, headers)
#     360
#     361
# --> 362     table = tables[0].reset_index(drop = True)
#     363
#     364     return table
#
# IndexError: list index out of range

# %%
dow_stats
# Out:
# {'GDRX':                    Attribute  Recent
#  0      Market Cap (intraday)  15.93B
#  1           Enterprise Value  15.72B
#  2               Trailing P/E  871.85
#  3                Forward P/E   75.19
#  4  PEG Ratio (5 yr expected)     NaN
#  5          Price/Sales (ttm)   24.08
#  6           Price/Book (mrq)   18.82
#  7   Enterprise Value/Revenue   22.92
#  8    Enterprise Value/EBITDA  -58.33,
#  'FTRP':                    Attribute   Recent
#  0      Market Cap (intraday)  196.39M
#  1           Enterprise Value  142.78M
#  2               Trailing P/E      NaN
#  3                Forward P/E      NaN
#  4  PEG Ratio (5 yr expected)      NaN
#  5          Price/Sales (ttm)    94.97
#  6           Price/Book (mrq)     2.72
#  7   Enterprise Value/Revenue    54.54
#  8    Enterprise Value/EBITDA    -3.68,
#  'PLTR':                    Attribute  Recent
#  0      Market Cap (intraday)  37.97B
#  1           Enterprise Value  35.75B
#  2               Trailing P/E  473.50
# ...

# %%
combined_stats = pd.concat(dow_stats)
combined_stats = combined_stats.reset_index()
combined_stats
# Out:
#     level_0  level_1                  Attribute  Recent
# 0      GDRX        0      Market Cap (intraday)  15.93B
# 1      GDRX        1           Enterprise Value  15.72B
# 2      GDRX        2               Trailing P/E  871.85
# 3      GDRX        3                Forward P/E   75.19
# 4      GDRX        4  PEG Ratio (5 yr expected)     NaN
# ..      ...      ...                        ...     ...
# 247    MGNI        4  PEG Ratio (5 yr expected)     NaN
# 248    MGNI        5          Price/Sales (ttm)    5.42
# 249    MGNI        6           Price/Book (mrq)    2.61
# 250    MGNI        7   Enterprise Value/Revenue    7.44
# 251    MGNI        8    Enterprise Value/EBITDA   40.13
#
# [252 rows x 4 columns]

# %%
del combined_stats["level_1"]
# update column names
combined_stats.columns = ["Ticker", "Attribute", "Recent"]
combined_stats
# Out:
#     Ticker                  Attribute  Recent
# 0     GDRX      Market Cap (intraday)  15.93B
# 1     GDRX           Enterprise Value  15.72B
# 2     GDRX               Trailing P/E  871.85
# 3     GDRX                Forward P/E   75.19
# 4     GDRX  PEG Ratio (5 yr expected)     NaN
# ..     ...                        ...     ...
# 247   MGNI  PEG Ratio (5 yr expected)     NaN
# 248   MGNI          Price/Sales (ttm)    5.42
# 249   MGNI           Price/Book (mrq)    2.61
# 250   MGNI   Enterprise Value/Revenue    7.44
# 251   MGNI    Enterprise Value/EBITDA   40.13
#
# [252 rows x 3 columns]

# %%
pe_ratios = combined_stats[combined_stats["Attribute"]=="Enterprise Value/EBITDA"].reset_index()
pe_ratios.head()
# Out:
#    index Ticker                Attribute  Recent
# 0      8   GDRX  Enterprise Value/EBITDA  -58.33
# 1     17   FTRP  Enterprise Value/EBITDA   -3.68
# 2     26   PLTR  Enterprise Value/EBITDA  -71.25
# 3     35   FLGC  Enterprise Value/EBITDA   -6.68
# 4     44   DOYU  Enterprise Value/EBITDA    0.10

# %%
pe_ratios_sorted = pe_ratios.sort_values('Recent',ascending=False)
pe_ratios_sorted.head()
# Out:
#     index Ticker                Attribute Recent
# 16    152   PINS  Enterprise Value/EBITDA  57.58
# 19    179    AMD  Enterprise Value/EBITDA  47.25
# 27    251   MGNI  Enterprise Value/EBITDA  40.13
# 8      80   DSGX  Enterprise Value/EBITDA  39.58
# 25    233     ZM  Enterprise Value/EBITDA  39.37

# %%
income_statement = si.get_income_statement("aapl")
income_statement
# Out:
# endDate                              2021-09-25    2020-09-26    2019-09-28  \
# Breakdown
# researchDevelopment                 21914000000   18752000000   16217000000
# effectOfAccountingCharges                  None          None          None
# incomeBeforeTax                    109207000000   67091000000   65737000000
# minorityInterest                           None          None          None
# netIncome                           94680000000   57411000000   55256000000
# sellingGeneralAdministrative        21973000000   19916000000   18245000000
# grossProfit                        152836000000  104956000000   98392000000
# ebit                               108949000000   66288000000   63930000000
# operatingIncome                    108949000000   66288000000   63930000000
# otherOperatingExpenses                     None          None          None
# interestExpense                     -2645000000   -2873000000   -3576000000
# ...

# %%
transposed = income_statement.transpose()
transposed
# Out:
# Breakdown  researchDevelopment effectOfAccountingCharges incomeBeforeTax  \
# endDate
# 2021-09-25         21914000000                      None    109207000000
# 2020-09-26         18752000000                      None     67091000000
# 2019-09-28         16217000000                      None     65737000000
# 2018-09-29         14236000000                      None     72903000000
#
# Breakdown  minorityInterest    netIncome sellingGeneralAdministrative  \
# endDate
# 2021-09-25             None  94680000000                  21973000000
# 2020-09-26             None  57411000000                  19916000000
# 2019-09-28             None  55256000000                  18245000000
# 2018-09-29             None  59531000000                  16705000000
#
# Breakdown    grossProfit          ebit operatingIncome otherOperatingExpenses  \
# endDate
# 2021-09-25  152836000000  108949000000    108949000000                   None
# ...

# %% [markdown]
# #### Financial Data

# %%
#Transform pf position symnols into a list
stock_symbol_list = portfolio_stock_df.symbol.to_list()

# %%
#Preview of columns to be extracted
for col in new_col_df:
    print(col)
# Out:
# zip
# sector
# fullTimeEmployees
# longBusinessSummary
# city
# phone
# state
# country
# companyOfficers
# website
# maxAge
# address1
# industry
# ebitdaMargins
# profitMargins
# grossMargins
# operatingCashflow
# revenueGrowth
# operatingMargins
# ebitda
# targetLowPrice
# recommendationKey
# grossProfits
# freeCashflow
# targetMedianPrice
# currentPrice
# earningsGrowth
# currentRatio
# returnOnAssets
# numberOfAnalystOpinions
# targetMeanPrice
# debtToEquity
# returnOnEquity
# targetHighPrice
# totalCash
# totalDebt
# totalRevenue
# totalCashPerShare
# financialCurrency
# revenuePerShare
# quickRatio
# recommendationMean
# exchange
# shortName
# longName
# exchangeTimezoneName
# exchangeTimezoneShortName
# isEsgPopulated
# gmtOffSetMilliseconds
# underlyingSymbol
# quoteType
# symbol
# underlyingExchangeSymbol
# headSymbol
# messageBoardId
# uuid
# market
# annualHoldingsTurnover
# enterpriseToRevenue
# beta3Year
# enterpriseToEbitda
# 52WeekChange
# morningStarRiskRating
# ...

# %%
#Create funtion for the 4 cells below

# %%
#Extract data from list of positions
sector =[]
for col in stock_symbol_list:
    msft = yf.Ticker(col)
    test = msft.info
    df = pd.DataFrame(test.items()).T
    headers = df.iloc[0]
    new_col_df  = pd.DataFrame(df.values[1:], columns=headers)
    new_col_df['symbol'] = col
    #new_df = new_df[['symbol', 'sector','fullTimeEmployees','city','country', 'industry']]
    new_df = new_col_df.reindex(columns=['longName',
                                         'symbol', 
                                         'sector',
                                         'fullTimeEmployees',
                                         'city',
                                         'country',
                                         'industry',
                                         'marketCap',
                                         'ebitdaMargins',
                                         'profitMargins',
                                         'grossMargins',
                                         'operatingCashflow',
                                         'revenueGrowth',
                                         'operatingMargins',
                                         'ebitda',
                                         'targetLowPrice',
                                         'recommendationKey',
                                         'grossProfits',
                                         'freeCashflow',
                                         'targetMedianPrice',
                                         'currentPrice',
                                         'earningsGrowth',
                                         'currentRatio',
                                         'returnOnAssets',
                                         'numberOfAnalystOpinions',
                                         'targetMeanPrice',
                                         'debtToEquity',
                                         'returnOnEquity',
                                         'targetHighPrice',
                                         'totalCash',
                                         'totalDebt',
                                         'totalRevenue',
                                         'totalCashPerShare',
                                         'financialCurrency',
                                         'revenuePerShare',
                                         'quickRatio'])
    sector.append(new_df)

# %%
appended_data = pd.concat(sector)

# %%
appended_data.to_pickle("./info_stock.pkl")
unpickled_df = pd.read_pickle("./info_stock.pkl")

# %%
porftolio_financials = portfolio_stock_df.merge(appended_data, how='left', on='symbol')

# %%
porftolio_financials.head(5)
# Out:
#          id positionType  size  price  value  breakEvenPrice  pct_of_total  \
# 0  18343191      PRODUCT     1     33     29              37             0
# 1  19790636      PRODUCT    20      2     43               5             0
# 2  18333971      PRODUCT     1     19     17              28             0
# 3  19433248      PRODUCT    10      2     16               4             0
# 4  16204538      PRODUCT   401      2    864               5             8
#
#                                      name symbol  \
# 0                     Goodrx Holdings Inc   GDRX
# 1  FIELD TRIP HEALTH LTD. - COMMON SHARES   FTRP
# 2               Palantir Technologies Inc   PLTR
# 3       FLORA GROWTH CORP. - COMMON STOCK   FLGC
# 4        Douyu International Holdings Ltd   DOYU
#
#                                longName  ... returnOnEquity targetHighPrice  \
# 0                 GoodRx Holdings, Inc.  ...             -0              53
# ...

# %% [markdown]
# ## Portfolio Analytics

# %%
porftolio_financials['unrealized_gains'] = round((porftolio_financials['price']-porftolio_financials['breakEvenPrice'])*porftolio_financials['size'],2)

# %%
#Group df by country
country_df = porftolio_financials.groupby('country').agg({'pct_of_total': 'sum',
                                    'value': 'sum',
                                    'unrealized_gains': 'sum',
                                    'marketCap': 'mean',
                                    'ebitdaMargins': 'median',
                                    'freeCashflow': 'mean',
                                    'numberOfAnalystOpinions': 'sum',
                                    'symbol': 'count',
                                    'revenuePerShare': 'median'})
country_df.head(20)
# Out:
# C:\Users\robin\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\robin\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#                pct_of_total  value  unrealized_gains   marketCap  \
# country
# Canada                    3    313              -264  1561270120
# China                    12   1245             -1309 74387191504
# Israel                   44   4481              -317  7223167104
# South Korea               1    130               -78 51702509568
# United States            38   3900             -2968 29473048436
# nan                       2    228                87         NaN
#
#                ebitdaMargins  freeCashflow  numberOfAnalystOpinions  symbol  \
# country
# Canada                     0      31639382                       22       5
# ...

# %%
#Reset index
country_df.reset_index(inplace=True)
country_df.rename(columns={"sector": "sector"}, inplace=True)
country_df.head(5)
# Out:
#                    sector  pct_of_total  value  unrealized_gains    marketCap  \
# 0  Communication Services            65   6715             -2384  18564443330
# 1       Consumer Cyclical             6    628              -625  66566371300
# 2      Financial Services             4    395              -588 113526164608
# 3              Healthcare             5    496              -455   4385281261
# 4             Industrials             1     99              -258   3591513344
#
#    ebitdaMargins  freeCashflow
# 0              0     285254560
# 1             -0    1278994944
# 2             -1    1663087568
# 3             -0      -5900144
# 4              0    -135281504

# %%
country_df.plot(x ='sector', y='marketCap', kind = 'barh', color = 'blue', 
        title = 'Unrealized Gains per Industry', 
        legend = True)

plt.title('Unrealized Gains per Industry')
plt.ylabel('Unrealized Gains')
plt.xlabel('Industry')

plt.show()

# %%
#function to get country codes
def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown' 
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown' 
    return (cn_a2_code, cn_continent)

country_codes_df = country_df.CountryName.apply(get_continent)
country_codes_df = country_codes_df.to_frame(name='Codes')
country_codes_df['Codes'] = country_codes_df['Codes'].astype(str)
country_codes_df
# Out:
#           Codes
# 0  ('CA', 'NA')
# 1  ('CN', 'AS')
# 2  ('IL', 'AS')
# 3  ('KR', 'AS')
# 4  ('US', 'NA')

# %%
country_codes_df.Codes= country_codes_df.Codes.str.replace(')','',regex=True)
country_codes_df.Codes= country_codes_df.Codes.str.replace('(','',regex=True)

# %%
country_codes_df
# Out:
#         Codes
# 0  'CA', 'NA'
# 1  'CN', 'AS'
# 2  'IL', 'AS'
# 3  'KR', 'AS'
# 4  'US', 'NA'

# %%
# Create two lists for the loop results to be placed
country_code = []
continent_code = []

# For each row in a varible,
for row in country_codes_df['Codes']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        country_code.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        continent_code.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        country_code.append(np.NaN)
        # append a missing value to lon
        continent_code.append(np.NaN)

# Create two new columns from lat and lon
country_codes_df['country_code'] = country_code
country_codes_df['continent_code'] = continent_code

country_codes_df
# Out:
#         Codes country_code continent_code
# 0  'CA', 'NA'         'CA'           'NA'
# 1  'CN', 'AS'         'CN'           'AS'
# 2  'IL', 'AS'         'IL'           'AS'
# 3  'KR', 'AS'         'KR'           'AS'
# 4  'US', 'NA'         'US'           'NA'

# %%
geo_map_df = pd.concat([country_codes_df,country_df], axis=1)

# %%
geo_map_df.head(5)
# Out:
#         Codes country_code continent_code    CountryName  pct_of_total  value  \
# 0  'CA', 'NA'         'CA'           'NA'         Canada             3    313
# 1  'CN', 'AS'         'CN'           'AS'          China            12   1245
# 2  'IL', 'AS'         'IL'           'AS'         Israel            44   4481
# 3  'KR', 'AS'         'KR'           'AS'    South Korea             1    130
# 4  'US', 'NA'         'US'           'NA'  United States            38   3900
#
#    unrealized_gains   marketCap
# 0              -264  1561270120
# 1             -1309 74387191504
# 2              -317  7223167104
# 3               -78 51702509568
# 4             -2968 29473048436

# %%
geo_map_df['CountryName'] = geo_map_df['CountryName'].astype(str)

# %%
user_agent = 'user_me_{}'.format(randint(10000,99999))
geolocator = Nominatim(user_agent=user_agent)

# %%
def geolocate(country):
    try:
        # Geolocate the center of the country
        loc = geolocator.geocode(country.CountryName)
       # And return latitude and longitude
        return (loc.latitude, loc.longitude)
    except:
        # Return missing value
        return np.nan
    
geo_temp_map_df = geo_map_df.apply(geolocate, axis = 1)

geo_map_df = geo_temp_map_df.to_frame(name='geo')
geo_map_df['geo'] = geo_map_df['geo'].astype(str)
geo_map_df
# Out:
#                          geo
# 0  (61.0666922, -107.991707)
# 1    (35.000074, 104.999927)
# 2   (31.5313113, 34.8667654)
# 3   (36.638392, 127.6961188)
# 4  (39.7837304, -100.445882)

# %%
geo_map_df.geo= geo_map_df.geo.str.replace(')','',regex=True)
geo_map_df.geo= geo_map_df.geo.str.replace('(','',regex=True)

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in geo_map_df['geo']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        lat.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        lon.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
geo_map_df['latitude'] = lat
geo_map_df['longitude'] = lon

# %%
geo_map_df.head()
# Out:
#                        geo    latitude     longitude
# 0  61.0666922, -107.991707  61.0666922   -107.991707
# 1    35.000074, 104.999927   35.000074    104.999927
# 2   31.5313113, 34.8667654  31.5313113    34.8667654
# 3   36.638392, 127.6961188   36.638392   127.6961188
# 4  39.7837304, -100.445882  39.7837304   -100.445882

# %%
geo_map_df = pd.concat([geo_map_df,country_df], axis=1)
geo_map_df
# Out:
#                        geo    latitude     longitude    CountryName  \
# 0  61.0666922, -107.991707  61.0666922   -107.991707         Canada
# 1    35.000074, 104.999927   35.000074    104.999927          China
# 2   31.5313113, 34.8667654  31.5313113    34.8667654         Israel
# 3   36.638392, 127.6961188   36.638392   127.6961188    South Korea
# 4  39.7837304, -100.445882  39.7837304   -100.445882  United States
#
#    pct_of_total  value  unrealized_gains   marketCap
# 0             3    313              -264  1561270120
# 1            12   1245             -1309 74387191504
# 2            44   4481              -317  7223167104
# 3             1    130               -78 51702509568
# 4            38   3900             -2968 29473048436

# %%
#empty map
world_map= folium.Map(tiles="cartodbpositron")
marker_cluster = MarkerCluster().add_to(world_map)
#for each coordinate, create circlemarker of user percent
for i in range(len(geo_map_df)):
        lat = geo_map_df.iloc[i]['latitude']
        long = geo_map_df.iloc[i]['longitude']
        radius=30
        popup_text = """Country : {}<br>
                    Portfolio Value : {}<br>"""
        popup_text = popup_text.format(geo_map_df.iloc[i]['CountryName'],
                                   geo_map_df.iloc[i]['value']
                                   )
        folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill =True).add_to(marker_cluster)
#show the map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### Country Mapping for all Stocks

# %%
porftolio_financials.head(5)
# Out:
#          id positionType  size  price  value  breakEvenPrice  pct_of_total  \
# 0  18343191      PRODUCT     1     33     29              37             0
# 1  19790636      PRODUCT    20      2     43               5             0
# 2  18333971      PRODUCT     1     19     17              28             0
# 3  19433248      PRODUCT    10      2     16               4             0
# 4  16204538      PRODUCT   401      2    864               5             8
#
#                                      name symbol  \
# 0                     Goodrx Holdings Inc   GDRX
# 1  FIELD TRIP HEALTH LTD. - COMMON SHARES   FTRP
# 2               Palantir Technologies Inc   PLTR
# 3       FLORA GROWTH CORP. - COMMON STOCK   FLGC
# 4        Douyu International Holdings Ltd   DOYU
#
#                                longName  ... returnOnEquity targetHighPrice  \
# 0                 GoodRx Holdings, Inc.  ...             -0              53
# ...

# %%
porftolio_financials['city'] = porftolio_financials['city'].astype(str)
porftolio_financials['country'] = porftolio_financials['country'].astype(str)

# %%
user_agent = 'user_me_{}'.format(randint(10000,99999))
geolocator = Nominatim(user_agent=user_agent)
def geolocate(country):
    try:
        # Geolocate the center of the country
        loc = geolocator.geocode(country.city+','+ country.country)
       # And return latitude and longitude
        return (loc.latitude, loc.longitude)
    except:
        # Return missing value
        return np.nan
    
geo_city_map_df = porftolio_financials.apply(geolocate, axis = 1)

geo_city_map_df = geo_city_map_df.to_frame(name='city_geo')
geo_city_map_df['city_geo'] = geo_city_map_df['city_geo'].astype(str)
geo_city_map_df
# Out:
#                                    city_geo
# 0                (34.0194704, -118.4912273)
# 1                 (43.6534817, -79.3839347)
# 2                (39.7392364, -104.9848623)
# 3                 (43.6534817, -79.3839347)
# 4                 (30.5951051, 114.2999353)
# 5                 (40.7127281, -74.0060152)
# 6                 (40.7539956, -79.8103943)
# 7                 (37.4863239, -122.232523)
# 8                 (43.4652699, -80.5222961)
# 9                 (40.7127281, -74.0060152)
# 10               (32.3140354, -106.7798078)
# 11                (37.7790262, -122.419906)
# 12                 (39.906217, 116.3912757)
# 13               (34.0194704, -118.4912273)
# 14                 (39.906217, 116.3912757)
# 15                (37.7790262, -122.419906)
# 16                (37.7790262, -122.419906)
# 17  (32.015910399999996, 34.78581210180328)
# 18                (40.7127281, -74.0060152)
# 19               (37.2333253, -121.6846349)
# ...

# %%
geo_city_map_df.city_geo= geo_city_map_df.city_geo.str.replace(')','',regex=True)
geo_city_map_df.city_geo= geo_city_map_df.city_geo.str.replace('(','',regex=True)

# %%
# Create two lists for the loop results to be placed
lat = []
lon = []

# For each row in a varible,
for row in geo_city_map_df['city_geo']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        lat.append(row.split(',')[0])
        # Split the row by comma and append
        # everything after the comma to lon
        lon.append(row.split(',')[1])
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        lon.append(np.NaN)

# Create two new columns from lat and lon
geo_city_map_df['latitude'] = lat
geo_city_map_df['longitude'] = lon

# %%
geo_city_map_df.head(5)
# Out:
#                    city_geo    latitude      longitude
# 0  34.0194704, -118.4912273  34.0194704   -118.4912273
# 1   43.6534817, -79.3839347  43.6534817    -79.3839347
# 2  39.7392364, -104.9848623  39.7392364   -104.9848623
# 3   43.6534817, -79.3839347  43.6534817    -79.3839347
# 4   30.5951051, 114.2999353  30.5951051    114.2999353

# %%
geo_map_2_df = pd.concat([geo_city_map_df,porftolio_financials], axis=1)
geo_map_2_df.head(5)
# Out:
#                    city_geo    latitude      longitude        id positionType  \
# 0  34.0194704, -118.4912273  34.0194704   -118.4912273  18343191      PRODUCT
# 1   43.6534817, -79.3839347  43.6534817    -79.3839347  19790636      PRODUCT
# 2  39.7392364, -104.9848623  39.7392364   -104.9848623  18333971      PRODUCT
# 3   43.6534817, -79.3839347  43.6534817    -79.3839347  19433248      PRODUCT
# 4   30.5951051, 114.2999353  30.5951051    114.2999353  16204538      PRODUCT
#
#    size  price  value  breakEvenPrice  pct_of_total  ... returnOnEquity  \
# 0     1     33     29              37             0  ...             -0
# 1    20      2     43               5             0  ...             -1
# 2     1     19     17              28             0  ...             -0
# 3    10      2     16               4             0  ...             -1
# 4   401      2    864               5             8  ...             -0
#
# ...

# %%
#empty map
world_map= folium.Map(tiles="cartodbpositron")
marker_cluster = MarkerCluster().add_to(world_map)
#for each coordinate, create circlemarker of user percent
for i in range(len(geo_map_2_df)):
        lat = geo_map_2_df.iloc[i]['latitude']
        long = geo_map_2_df.iloc[i]['longitude']
        radius=30
        popup_text = """Country : {}<br>
                    City : {}<br>
                    Portfolio Value : {}<br>"""
        popup_text = popup_text.format(geo_map_2_df.iloc[i]['country'],
                                       geo_map_2_df.iloc[i]['city'],
                                   geo_map_2_df.iloc[i]['value']
                                   )
        folium.CircleMarker(location = [lat, long], radius=radius, popup= popup_text, fill =True).add_to(marker_cluster)
#show the map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ____________________

# %% [markdown]
# ## Web Scrapping

# %%
stock_symbol_list = portfolio_stock_df.symbol.to_list()

# %%
#stock_symbol_list = portfolio_stock_df.symbol.to_list()
sector =[]
for item in stock_symbol_list:
    temp_var = item + '/' 
    url='https://finance.yahoo.com/quote/{0}'.format(temp_var)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    sector.append(item)
    for entry in soup.find_all('span', {'class':'Fw(600)'}):
        if len(entry.text) >= 2 and entry.text != 'Morningstar' and entry.text != 'Argus Research':
            sector.append(entry.text)
sector
# Out:
# ['GDRX',
#  'Healthcare',
#  'Health Information Services',
#  '450',
#  'FTRP',
#  'Healthcare',
#  'Medical Care Facilities',
#  '104',
#  'PLTR',
#  'Technology',
#  'Software—Infrastructure',
#  '2,733',
#  'FLGC',
#  'Healthcare',
#  'Drug Manufacturers—Specialty & Generic',
#  'DOYU',
#  'Communication Services',
#  'Internet Content & Information',
#  '1,877',
#  'NYT',
#  'IIVI',
#  'Technology',
#  'Scientific & Technical Instruments',
#  '22,961',
#  'POSH',
#  'Consumer Cyclical',
#  'Internet Retail',
#  '558',
#  'DSGX',
#  'LMND',
#  'Financial Services',
#  'Insurance—Property & Casualty',
#  '567',
#  'SPCE',
#  'Industrials',
#  'Aerospace & Defense',
#  '823',
#  'NVTA',
#  'Healthcare',
#  'Diagnostics & Research',
#  '2,900',
#  'JD',
#  'Consumer Cyclical',
#  'Internet Retail',
#  '314,906',
#  'ATVI',
#  'Communication Services',
#  'Electronic Gaming & Multimedia',
#  '9,500',
#  'BIDU',
#  'Communication Services',
#  'Internet Content & Information',
# ...

# %% [markdown]
# ### Portfolio Analysis - Unrealized Gains

# %% [markdown]
# ##### Ideas:
# 1. Industry
# 2. IPO
# 3. Last 12 months return
# 4. ...

# %%
portfolio_stock_df['unrealized_gains'] = round((portfolio_stock_df['price']-portfolio_stock_df['breakEvenPrice'])*portfolio_stock_df['size'],2)

# %%
#Total Value of Portfolio
round(portfolio_stock_df['value'].sum(),2)
# Out:
# 10296.88

# %%
#Total Value of Unrealized Gains
round(portfolio_stock_df['unrealized_gains'].sum(),2)
# Out:
# -4850.19

# %%
#Assign Quantiles to the Stocks % of total
quantiles = pd.qcut(portfolio_stock_df['pct_of_total'], 4, labels=False)
portfolio_stock_df = portfolio_stock_df.assign(quantile=quantiles.values)
portfolio_stock_df.head()
# Out:
#          id positionType   size  price       value  breakEvenPrice  \
# 0  18343191      PRODUCT    1.0  38.42   33.974806       36.710000
# 1  19790636      PRODUCT   20.0   3.15   55.710900        5.210000
# 2  18333971      PRODUCT    1.0  18.98   16.784014       28.311741
# 3  19433248      PRODUCT   10.0   1.94   17.155420        3.892857
# 4  16204538      PRODUCT  401.0   2.27  804.951761        5.211147
#
#    pct_of_total                                    name symbol  \
# 0          0.34                     Goodrx Holdings Inc   GDRX
# 1          0.56  FIELD TRIP HEALTH LTD. - COMMON SHARES   FTRP
# 2          0.17               Palantir Technologies Inc   PLTR
# 3          0.17       FLORA GROWTH CORP. - COMMON STOCK   FLGC
# 4          8.04        Douyu International Holdings Ltd   DOYU
#
#    unrealized_gains  quantile
# 0              1.71         0
# 1            -41.20         1
# 2             -9.33         0
# 3            -19.53         0
# ...

# %%
#Overlayed Distribution by quantile
sb.displot(
  data=portfolio_stock_df,
  x="pct_of_total",
  hue="quantile",
  kind="hist",
  aspect=1.4,
  log_scale=10,
  bins=50
)

# %%
#Distributions by quantile
sb.displot(
  data=portfolio_stock_df,
  x="pct_of_total",
  col="quantile",
  kind="hist",
  aspect=1.4,
  log_scale=10,
  bins=50
)

# %% [markdown]
# ### Transactions

# %%
transactions = degiro.transactions(datetime(2018, 1, 1), datetime.now())

# %%
transactions_df = pd.DataFrame(transactions)

# %%
transactions_df.describe()
# Out:
#              id  productId  price  quantity  total  orderTypeId  fxRate  \
# count       878        878    878       878    878          870     878
# mean  212775126   11800514    112         1     12            2       1
# std    43815275    6096268    173      1204   1502            1       1
# min   153439824     255429      0    -30000  -8075            0       0
# 25%   165881232    5657484     27        -5   -586            2       1
# 50%   208129486   14652504     66         1   -103            2       1
# 75%   238868896   16082944    146        10    481            2       1
# max   324881842   21151958   2294     15000  11467            2      11
#
#        totalInBaseCurrency  feeInBaseCurrency  totalPlusFeeInBaseCurrency  \
# count                  878                852                         878
# mean                     6                 -1                           6
# std                   1226                  1                        1226
# ...

# %%
transactions_df.head()
# Out:
#           id  productId                       date buysell  price  quantity  \
# 0  153439824   13433777  2019-04-04T15:30:00+02:00       B     22        15
# 1  153514251    1156277  2019-04-04T17:34:27+02:00       B     85         5
# 2  153946118    1135199  2019-04-10T15:39:10+02:00       B    179         1
# 3  153946119    1135199  2019-04-10T15:39:10+02:00       B    179         2
# 4  154053075    1140987  2019-04-11T15:33:43+02:00       B     91         6
#
#    total  orderTypeId counterParty  transfered  fxRate  totalInBaseCurrency  \
# 0   -330            2           MK       False       1                 -294
# 1   -424            2           MK       False       1                 -378
# 2   -179            2           MK       False       1                 -159
# 3   -358            2           MK       False       1                 -318
# 4   -543            2           MK       False       1                 -482
#
# ...

# %%
stock_id_df.head(5)
# Out:
#          id                                    name symbol
# 0  18343191                     Goodrx Holdings Inc   GDRX
# 1  19790636  FIELD TRIP HEALTH LTD. - COMMON SHARES   FTRP
# 2  18333971               Palantir Technologies Inc   PLTR
# 3  19433248       FLORA GROWTH CORP. - COMMON STOCK   FLGC
# 4  16204538        Douyu International Holdings Ltd   DOYU

# %%
stock_id_df['id'] = stock_id_df['id'].astype(str)
transactions_df['productId'] = transactions_df['productId'].astype(str)
# Out:
# C:\Users\robin\AppData\Local\Temp/ipykernel_17516/3910155508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_id_df['id'] = stock_id_df['id'].astype(str)

# %%
portfolio_stock_df = stock_id_df.merge(transactions_df, left_on='id', right_on='productId')
portfolio_stock_df
# Out:
#          id_x                                    name symbol       id_y  \
# 0    18343191                     Goodrx Holdings Inc   GDRX  278837149
# 1    19790636  FIELD TRIP HEALTH LTD. - COMMON SHARES   FTRP  305814805
# 2    18333971               Palantir Technologies Inc   PLTR  231469542
# 3    18333971               Palantir Technologies Inc   PLTR  237485113
# 4    18333971               Palantir Technologies Inc   PLTR  238295661
# ..        ...                                     ...    ...        ...
# 503   5249449               Alibaba Group Holding Ltd   BABA  238823922
# 504   5249449               Alibaba Group Holding Ltd   BABA  243033183
# 505   5249449               Alibaba Group Holding Ltd   BABA  246466220
# 506  11674699                      Coupa Software Inc   COUP  248226009
# 507  11674699                      Coupa Software Inc   COUP  249649305
#
#     productId                       date buysell  price  quantity  total  \
# ...

# %%
profit_df = portfolio_stock_df.groupby(by=['symbol', 'buysell']).agg({'total': 'sum'})
profit_df.head(5)
# Out:
#                 total
# symbol buysell
# ADE    B        -5543
#        S         6309
# AMD    B         -708
#        S          682
# ATVI   B        -3349

# %%
profit_df['total'] = profit_df['total'].abs()
profit_df['diffs'] = profit_df['total'].diff()

# %%
profit_df
# Out:
#    symbol buysell  total  diffs
# 0     ADE       B   5543    NaN
# 1     ADE       S   6309    767
# 2     AMD       B    708  -5601
# 3     AMD       S    682    -26
# 4    ATVI       B   3349   2667
# ..    ...     ...    ...    ...
# 85    WIX       S   2157   -329
# 86     ZM       B  12306  10149
# 87     ZM       S  12321     15
# 88   ZNGA       B   3675  -8646
# 89   ZNGA       S   3614    -61
#
# [90 rows x 4 columns]

# %%
profit_df.reset_index(inplace=True)
profit_df
# Out:
#     index symbol buysell  total  diffs
# 0       0    ADE       B   5543    NaN
# 1       1    ADE       S   6309    767
# 2       2    AMD       B    708  -5601
# 3       3    AMD       S    682    -26
# 4       4   ATVI       B   3349   2667
# ..    ...    ...     ...    ...    ...
# 85     85    WIX       S   2157   -329
# 86     86     ZM       B  12306  10149
# 87     87     ZM       S  12321     15
# 88     88   ZNGA       B   3675  -8646
# 89     89   ZNGA       S   3614    -61
#
# [90 rows x 5 columns]

# %%
profit_df = profit_df[profit_df['buysell']=='S']

# %%
profit_df.head()
# Out:
#    index symbol buysell  total  diffs
# 1      1    ADE       S   6309    767
# 3      3    AMD       S    682    -26
# 5      5   ATVI       S   3108   -241
# 7      7    AYX       S   9958    555
# 9      9   BABA       S   6630   -355

# %%
total_pf = profit_df['diffs'].sum()
print (total_pf)
# Out:
# 8190.107500000006

# %% [markdown]
# ### Transactions Analysis
